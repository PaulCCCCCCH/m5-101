# %%
from bs4 import BeautifulSoup

# %%
with open('./douban.html') as f:
    soup = BeautifulSoup(f)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="ua-linux ua-webkit" lang="zh-CN">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="webkit" name="renderer"/>
#   <meta content="always" name="referrer"/>
#   <meta content="ok0wCgT20tBBgo9_zat2iAcimtN4Ftf5ccsh092Xeyw" name="google-site-verification"/>
#   <title>
#    豆瓣电影 Top 250
#   </title>
#   <meta content="cZdR4xxR7RxmM4zE" name="baidu-site-verification"/>
#   <meta content="no-cache" http-equiv="Pragma"/>
#   <meta content="Sun, 6 Mar 2005 01:00:00 GMT" http-equiv="Expires"/>
#   <link href="https://img3.doubanio.com/f/movie/d59b2715fdea4968a450ee5f6c95c7d7a2030065/pics/movie/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link href="https://img3.doubanio.com/f/shire/6522c42d2aba9757aeefa0c35cc0cefc9229747c/css/douban.css" rel="stylesheet" type="text/css"/>
# ...

# %%
import re
soup.findAll("a", href=re.compile("1[0-9]*2\/$"))
# Out:
# [<a href="https://movie.douban.com/subject/1291572/">
#  <img alt="指环王2：双塔奇兵" class="" src="https://img9.doubanio.com/view/photo/s_ratio_poster/public/p2640236255.jpg" width="100"/>
#  </a>,
#  <a class="" href="https://movie.douban.com/subject/1291572/">
#  <span class="title">詹军</span>
#  <span class="title"> / The Lord of the Rings: The Two Towers</span>
#  <span class="other"> / 魔戒二部曲：双城奇谋  /  指环王II：双塔</span>
#  </a>,
#  <a href="https://movie.douban.com/subject/1292402/">
#  <img alt="西西里的美丽传说" class="" src="https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2441988159.jpg" width="100"/>
#  </a>,
#  <a class="" href="https://movie.douban.com/subject/1292402/">
#  <span class="title">西西里的美丽传说</span>
#  <span class="title"> / Malèna</span>
#  <span class="other"> / 真爱伴我行(台)  /  玛莲娜</span>
#  </a>]

# %%
soup.find_all('a')[2].get('href')
# Out:
# 'https://www.douban.com/doubanapp/app?channel=qipao'
